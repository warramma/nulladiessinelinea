# %% [markdown]
# # 141. Linked List Cycle
# - Easy
# - Given head, the head of a linked list, determine if the linked list has a cycle in it.
#
# There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to. Note that pos is not passed as a parameter.
#
# Return true if there is a cycle in the linked list. Otherwise, return false.

# %%
def hasCycle(head):
    nodes_map = {}
    current = head
    while current.next is not None:
    #careful! remember that nodes CAN have the same values!
        if current in nodes_map:
            return True
        else:
            nodes_map[current] = 1
        #don't forget to go to the next node!!!
        current = current.next
    return False

# %% [markdown]
# # 83. Remove Duplicates from Sorted List
# - Easy
# - Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.

# %%
def deleteDuplicates(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        if head is None:
            return head
        previous = head
        current = head.next
        while current:
            if previous.val == current.val:
                previous.next = current.next
            else:
                previous = previous.next
            current = current.next
        return head

# %% [markdown]
# # 203. Remove Linked List Elements
# - Easy
#
# Given the head of a linked list and an integer val, remove all the nodes of the linked list that has Node.val == val, and return the new head.

# %%
def removeElements(self, head, val):
        """
        :type head: Optional[ListNode]
        :type val: int
        :rtype: Optional[ListNode]
        """
        if head is None:
            return head
        temp = ListNode(None, head)
        previous = temp
        current = head
        while current:
            if current.val == val:
                previous.next = current.next
            else:
                previous = previous.next
            current = current.next
        return temp.next

        '''
        temp-> head
        previous = None
        current = 1
        current != 6 so 
        previous = previous.next = temp.next = 1
        current = 2
        ===2====
        current = 2 !=6 so 
        previous = previous.next = 2
        current = 6
        ===3===
        current == 6 SO
        previous.next = current.next = 3
        current = current.next = 3
        (now previous = 2, current, 3, effectively dropping 6)
        ===4===
        previous = 3
        current = 4
        ==5===
        previous = 4
        current = 5
        ===6===
        previous = 5
        current = 6
        ===7====
        current == 6 SO
        previous.next = current.next = NONE
        current = None
        ===LOOP ENDS===
        '''

# %% [markdown]
# # 234 - linked list palindrome

# %%
def isPalindrome(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: bool
        """
        stack = []
        current = head
        while current: 
            stack.append(current.val)
            current = current.next
        
        current = head
        while current:
            if stack[-1] == current.val:
                stack.pop()
            else:
                return False
            current = current.next
        return True
